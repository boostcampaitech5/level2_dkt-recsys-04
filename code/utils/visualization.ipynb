# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# CSV 파일 경로 설정
PATH = "/opt/ml/level2_dkt-recsys-04/hptine_LQTM_ver4.csv"

# CSV 파일 읽기
data = pd.read_csv(PATH)

# 막대 그래프 그리기
plt.bar(data['id'], data['prediction'])#np.where(pred >= 0.5, 1, 0)

# 그래프 타이틀 및 축 제목 설정
plt.title("Output CatBoost")
plt.xlabel("userID")
plt.ylabel("prediction")

# 그래프 출력
plt.show()

# %%
# displot으로 분포 시각화
sns.displot(data['prediction'])

# %%
sns.lineplot(data['prediction'])
# Out:
# <Axes: ylabel='prediction'>

# %%
sns.kdeplot(data['prediction'])
# Out:
# <Axes: xlabel='prediction', ylabel='Density'>

# %%
sns.scatterplot(data['prediction'])
# Out:
# <Axes: ylabel='prediction'>

# %%
# CSV 파일 경로 설정
PATH = "/opt/ml/level2_dkt-recsys-04/code/boosting/outputs/CatBoost/20230524_182650_0.823732_catboost_oof_0.7_seed_42.csv"

# CSV 파일 읽기
data = pd.read_csv(PATH)

# 막대 그래프 그리기
plt.bar(data['id'], data['prediction'])#np.where(pred >= 0.5, 1, 0)

# 그래프 타이틀 및 축 제목 설정
plt.title("Output CatBoost")
plt.xlabel("userID")
plt.ylabel("prediction")

# 그래프 출력
plt.show()

# %%
# displot으로 분포 시각화
sns.displot(data['prediction'])

# %%
sns.lineplot(data['prediction'])
# Out:
# <Axes: ylabel='prediction'>

# %%
sns.kdeplot(data['prediction'])
# Out:
# <Axes: xlabel='prediction', ylabel='Density'>

# %%
sns.scatterplot(data['prediction'])
# Out:
# <Axes: ylabel='prediction'>
